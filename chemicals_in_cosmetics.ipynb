# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/PROJECTS/archive (3).zip')
df
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 0        41524   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1        41523                         Glover's Medicated Shampoo      NaN
# 2        41523                         Glover's Medicated Shampoo      NaN
# 3        41523           PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4        41523        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                                ...      ...
# 114630       5               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631       4               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632       3               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633       3               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634       2  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
# ...

# %%
df.dtypes
# Out:
# CDPHId                      int64
# ProductName                object
# CSFId                     float64
# CSF                        object
# CompanyId                   int64
# CompanyName                object
# BrandName                  object
# PrimaryCategoryId           int64
# PrimaryCategory            object
# SubCategoryId               int64
# SubCategory                object
# CasId                       int64
# CasNumber                  object
# ChemicalId                  int64
# ChemicalName               object
# InitialDateReported        object
# MostRecentDateReported     object
# DiscontinuedDate           object
# ChemicalCreatedAt          object
# ChemicalUpdatedAt          object
# ChemicalDateRemoved        object
# ChemicalCount               int64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 0        41524   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1        41523                         Glover's Medicated Shampoo      NaN
# 2        41523                         Glover's Medicated Shampoo      NaN
# 3        41523           PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4        41523        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                                ...      ...
# 114630       5               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631       4               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632       3               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633       3               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634       2  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
# ...

# %%
df.isna().sum()
# Out:
# CDPHId                         0
# ProductName                    0
# CSFId                      33973
# CSF                        34397
# CompanyId                      0
# CompanyName                    0
# BrandName                    216
# PrimaryCategoryId              0
# PrimaryCategory                0
# SubCategoryId                  0
# SubCategory                    0
# CasId                          0
# CasNumber                   6476
# ChemicalId                     0
# ChemicalName                   0
# InitialDateReported            0
# MostRecentDateReported         0
# DiscontinuedDate          101715
# ChemicalCreatedAt              0
# ChemicalUpdatedAt              0
# ChemicalDateRemoved       111650
# ChemicalCount                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CDPHId', 'ProductName', 'CSFId', 'CSF', 'CompanyId', 'CompanyName',
#        'BrandName', 'PrimaryCategoryId', 'PrimaryCategory', 'SubCategoryId',
#        'SubCategory', 'CasId', 'CasNumber', 'ChemicalId', 'ChemicalName',
#        'InitialDateReported', 'MostRecentDateReported', 'DiscontinuedDate',
#        'ChemicalCreatedAt', 'ChemicalUpdatedAt', 'ChemicalDateRemoved',
#        'ChemicalCount'],
#       dtype='object')

# %%
#it has many more null value ,so its better to drop
df.drop(['ChemicalDateRemoved'],axis=1,inplace=True)
df.drop(['DiscontinuedDate'],axis=1,inplace=True)

# remove id columns

df.drop(['CDPHId', 'CSFId','CompanyId','PrimaryCategoryId','ChemicalId','SubCategoryId','CasNumber','CasId'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# ProductName                   0
# CSF                       34397
# CompanyName                   0
# BrandName                   216
# PrimaryCategory               0
# SubCategory                   0
# ChemicalName                  0
# InitialDateReported           0
# MostRecentDateReported        0
# ChemicalCreatedAt             0
# ChemicalUpdatedAt             0
# ChemicalCount                 0
# dtype: int64

# %%
# handling missing

df['CSF']=df['CSF'].fillna(df['CSF'].mode()[0])
df['BrandName']=df['BrandName'].fillna(df['BrandName'].mode()[0])

# %%
df.isna().sum()
# Out:
# ProductName               0
# CSF                       0
# CompanyName               0
# BrandName                 0
# PrimaryCategory           0
# SubCategory               0
# ChemicalName              0
# InitialDateReported       0
# MostRecentDateReported    0
# ChemicalCreatedAt         0
# ChemicalUpdatedAt         0
# ChemicalCount             0
# dtype: int64

# %%
df
# Out:
#                                               ProductName           CSF  \
# 0        ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES         Black
# 1                              Glover's Medicated Shampoo         Black
# 2                              Glover's Medicated Shampoo         Black
# 3                PRECISION GLIMMER EYE LINER-ALL SHADES �         Black
# 4             AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �         Black
# ...                                                   ...           ...
# 114630               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK     Rosa Soft
# 114631               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  Malva Spirit
# 114632               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  Rojo Fashion
# 114633               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  Terra Mystic
# 114634  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...         Black
#
#                          CompanyName  BrandName  \
# 0                       New Avon LLC       AVON
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['PrimaryCategory'],df['ChemicalCount'])
plt.xticks(rotation=90)
plt.title('Chemicalcount in PrimaryCategory products')
plt.xlabel('products details')
plt.ylabel('chemical count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.distplot(df['ChemicalCount'],bins=10,color='g')
plt.title('Distribution of Chemicalcount')
plt.show()

# %%
df_head=df['BrandName'].head(41)

plt.figure(figsize=(12, 6))
sns.countplot(x=df_head,data=df)
plt.xticks(rotation=90)
plt.title('Top 10 Brand Names count')
plt.xlabel('10 Brand Names in df')

plt.show()

# %%
# sns.jointplot(x='SubCategory',y='CompanyName',data=df,hue='ChemicalCount')

# %%
 # conv  obj to  numeric


from sklearn.preprocessing  import LabelEncoder
le=LabelEncoder()
df['ProductName']=le.fit_transform(df['ProductName'])
df['CSF']=le.fit_transform(df['CSF'])
df['CompanyName']=le.fit_transform(df['CompanyName'])
df['BrandName']=le.fit_transform(df['BrandName'])
df['PrimaryCategory']=le.fit_transform(df['PrimaryCategory'])
df['ChemicalName']=le.fit_transform(df['ChemicalName'])
df['SubCategory']=le.fit_transform(df['SubCategory'])
df['InitialDateReported']=le.fit_transform(df['InitialDateReported'])
df['MostRecentDateReported']=le.fit_transform(df['MostRecentDateReported'])
df['ChemicalCreatedAt']=le.fit_transform(df['ChemicalCreatedAt'])
df['ChemicalUpdatedAt']=le.fit_transform(df['ChemicalUpdatedAt'])
df
# Out:
#         ProductName    CSF  CompanyName  BrandName  PrimaryCategory  \
# 0             30981   8264          372         82                5
# 1             13104   8264          252       1023                3
# 2             13104   8264          252       1023                3
# 3             22843   8264          372         82                5
# 4              1328   8264          372         82                5
# ...             ...    ...          ...        ...              ...
# 114630        13606  25418          579       2579                5
# 114631        13606  19609          579       2579                5
# 114632        13606  25381          579       2579                5
# 114633        13606  29362          579       2579                5
# 114634        21965   8264          527       1730                1
#
#         SubCategory  ChemicalName  InitialDateReported  \
# 0                40           110                 1015
# ...

# %%
df.dtypes
# Out:
# ProductName               int64
# CSF                       int64
# CompanyName               int64
# BrandName                 int64
# PrimaryCategory           int64
# SubCategory               int64
# ChemicalName              int64
# InitialDateReported       int64
# MostRecentDateReported    int64
# ChemicalCreatedAt         int64
# ChemicalUpdatedAt         int64
# ChemicalCount             int64
# dtype: object

# %%
df.corr()
# Out:
#                         ProductName       CSF  CompanyName  BrandName  \
# ProductName                1.000000  0.073330     0.066128   0.248462
# CSF                        0.073330  1.000000     0.030213   0.161831
# CompanyName                0.066128  0.030213     1.000000   0.311569
# BrandName                  0.248462  0.161831     0.311569   1.000000
# PrimaryCategory            0.020627 -0.039265    -0.041826  -0.059063
# SubCategory                0.029611 -0.065890    -0.059401  -0.101425
# ChemicalName               0.018293  0.041025    -0.023860   0.037076
# InitialDateReported       -0.013420  0.001848    -0.054618   0.027390
# MostRecentDateReported     0.013276  0.070765     0.031439   0.015226
# ChemicalCreatedAt         -0.019770  0.000769    -0.058616   0.016535
# ChemicalUpdatedAt         -0.004358  0.020367    -0.035747   0.028769
# ChemicalCount              0.032945 -0.008651     0.057417  -0.000648
#
# ...

# %%
# heatmap
sns.heatmap(df.corr(),annot=True,fmt='.2f' ,linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
X=df.iloc[:,:-1]
X
# Out:
#         ProductName    CSF  CompanyName  BrandName  PrimaryCategory  \
# 0             30981   8264          372         82                5
# 1             13104   8264          252       1023                3
# 2             13104   8264          252       1023                3
# 3             22843   8264          372         82                5
# 4              1328   8264          372         82                5
# ...             ...    ...          ...        ...              ...
# 114630        13606  25418          579       2579                5
# 114631        13606  19609          579       2579                5
# 114632        13606  25381          579       2579                5
# 114633        13606  29362          579       2579                5
# 114634        21965   8264          527       1730                1
#
#         SubCategory  ChemicalName  InitialDateReported  \
# 0                40           110                 1015
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0         1
# 1         2
# 2         2
# 3         1
# 4         1
#          ..
# 114630    1
# 114631    1
# 114632    1
# 114633    1
# 114634    1
# Name: ChemicalCount, Length: 114635, dtype: int64

# %%
# scale

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X)
x_scaled=scaler.transform(X)
x_scaled
# Out:
# array([[0.9189085 , 0.241334  , 0.61487603, ..., 0.63573725, 0.50194049,
#         0.49892473],
#        [0.38866973, 0.241334  , 0.41652893, ..., 0.48553055, 0.4829668 ,
#         0.48129032],
#        [0.38866973, 0.241334  , 0.41652893, ..., 0.48553055, 0.4851229 ,
#         0.48344086],
#        ...,
#        [0.40355925, 0.74120258, 0.95702479, ..., 0.45705099, 0.45579991,
#         0.45247312],
#        [0.40355925, 0.85745992, 0.95702479, ..., 0.45705099, 0.45579991,
#         0.45247312],
#        [0.65149043, 0.241334  , 0.87107438, ..., 0.46669729, 0.46528676,
#         0.46236559]])

# %%
# train test split

from sklearn.model_selection import train_test_split
x_scaled_train,x_scaled_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=1)

# %%
# create model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
